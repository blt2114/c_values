# %%
import numpy as np
from scipy import optimize, stats
import tensorflow as tf

import sys
sys.path.append("../src/")
import logistic_regression as lr
import affine_operator_win_bounds as affine_ops

# %%
def where_bya_breaks(win, C, Sigma, beta_MLE):
    D = Sigma.shape[0]
    A, b, d = np.eye(D), np.zeros(D), np.zeros(D)
    def bya(alpha):
        bya_val = affine_ops.b_bound(A, b, C, d, Sigma, beta_MLE, alpha)[0]
        assert np.isclose(bya_val, np.real(bya_val))
        return np.real(bya_val)
    c_upper_bound =  1-(1e-10)
    if win>bya(1-c_upper_bound): return 1-c_upper_bound
    if win<bya(c_upper_bound): return c_upper_bound
    
    
    where_breaks = optimize.bisect(
        f=lambda alpha: bya(alpha)-win,
        a=c_upper_bound, b=1-c_upper_bound, xtol=1e-3)
    return where_breaks

def wins_and_c_value_breaks_pts(X, Y, beta):
    """wins_and_c_value_breaks_pts, computes three estimates and compares them.
    
    The three estimates are the MLE, MAP, and our approximation
    """
    # Compute the estimates
    beta_MLE, beta_MAP = lr.MLE(X, Y), lr.MAP(X, Y)
    beta_tilde, C, H = lr.approx_post_mean(X, Y, beta_MLE, return_tranform_and_cov=True)
    Sigma = np.linalg.inv(H)
    
    # Compute wins 
    W_MAP_to_MLE = np.linalg.norm(beta_MLE-beta)**2 - np.linalg.norm(beta_MAP-beta)**2
    W_tilde_to_MLE = np.linalg.norm(beta_MLE-beta)**2 - np.linalg.norm(beta_tilde-beta)**2
    
    # Compute alphas where bounds break
    bya_break_MAP = where_bya_breaks(W_MAP_to_MLE, C, Sigma, beta_MLE)
    bya_break_tilde = where_bya_breaks(W_tilde_to_MLE, C, Sigma, beta_MLE)
    
    # Compute c-value
    A, b, d = np.eye(D), np.zeros(D), np.zeros(D)
    c_value = affine_ops.c_value(beta_MLE, A, b, C, d, Sigma)
    
    return W_MAP_to_MLE, W_tilde_to_MLE, bya_break_MAP, bya_break_tilde, c_value

# %%
def compare_wins_and_bya_breaks(N=100, D=10, sigma_x=0.25, sigma_beta=1, n_reps=10):
    
    # Simulate beta
    np.random.seed(42)
    beta = np.random.normal(size=D)*sigma_beta
    
    Ws_MAP_to_MLE, Ws_tilde_to_MLE, byas_break_MAP, byas_break_tilde = [], [], [], []
    c_values = []
    
    print("beta:", beta)
    for rep in range(n_reps):
        if (rep+1)%(n_reps/25)==0: print("rep %02d/%02d"%(rep+1, n_reps))
        X, Y = lr.gen_data(N, beta, sigma_x)
        X, Y = tf.convert_to_tensor(X), tf.convert_to_tensor(Y)
        
        W_MAP_to_MLE, W_tilde_to_MLE, bya_break_MAP, bya_break_tilde, c_value = wins_and_c_value_breaks_pts(
            X, Y, beta)
        Ws_MAP_to_MLE.append(W_MAP_to_MLE)
        Ws_tilde_to_MLE.append(W_tilde_to_MLE)
        byas_break_MAP.append(bya_break_MAP)
        byas_break_tilde.append(bya_break_tilde)
        c_values.append(c_value)
    return Ws_MAP_to_MLE, Ws_tilde_to_MLE, byas_break_MAP, byas_break_tilde, c_values

# %%
def plot_bya_breaks(byas_break, title):
    by_breaks=np.array(byas_break)
    alpha_grid = np.linspace(0, 1, 50)
    perc_break_by_alpha = np.array([np.mean(by_breaks>=alpha_break) for alpha_break in alpha_grid])
    coverage_by_alpha = 1-perc_break_by_alpha
    plt.figure(figsize=[6.5/3,6.5/4])
    plt.plot(alpha_grid, coverage_by_alpha, label="Actual")
    plt.plot([0,1],[0, 1], 'k--', label="Nominal")
    plt.xlabel(r"Confidence Level ($\alpha$)")
    plt.ylabel(r"Coverage ($\mathbb{P} \left[ W \ge b(y, \alpha)\right]$)")
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend(loc='lower right')
    plt.title(title)
    plt.show()

# %%
N, D, = 1000, 25
sigma_x, sigma_beta = 1./D, np.sqrt(1/2)
n_reps =  2500

Ws_MAP_to_MLE, Ws_tilde_to_MLE, byas_break_MAP, byas_break_tilde, c_values = compare_wins_and_bya_breaks(
    N=N, D=D, sigma_x=sigma_x, sigma_beta=sigma_beta, n_reps=n_reps)
# Out:
# beta: [ 0.35122995 -0.09776762  0.45798496  1.07694474 -0.16557144 -0.16555983
#   1.11667209  0.5426583  -0.33196852  0.38364789 -0.32768579 -0.32932067
#   0.17109316 -1.35289344 -1.2197011  -0.39759732 -0.71617975  0.22220642
#  -0.64206998 -0.99864952  1.03637018 -0.15964795  0.04774965 -1.0074491
#  -0.38493672]
# /home/btrippe/.conda/envs/hail/lib/python3.7/site-packages/scipy/optimize/zeros.py:550: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
# rep 100/2500
# roots: [-56.89293349+20.30999201j -56.89293349-20.30999201j]
# returning zero as the upper bound
# roots: [-44.64776632+31.16655479j -44.64776632-31.16655479j]
# returning zero as the upper bound
# roots: [-30.12022389+35.29074055j -30.12022389-35.29074055j]
# returning zero as the upper bound
# roots: [-14.37965328+32.64914529j -14.37965328-32.64914529j]
# returning zero as the upper bound
# roots: [2.1105746+18.61333954j 2.1105746-18.61333954j]
# returning zero as the upper bound
# roots: [-56.89293349+20.30999201j -56.89293349-20.30999201j]
# returning zero as the upper bound
# roots: [-44.64776632+31.16655479j -44.64776632-31.16655479j]
# returning zero as the upper bound
# roots: [-30.12022389+35.29074055j -30.12022389-35.29074055j]
# returning zero as the upper bound
# roots: [-14.37965328+32.64914529j -14.37965328-32.64914529j]
# returning zero as the upper bound
# roots: [2.1105746+18.61333954j 2.1105746-18.61333954j]
# returning zero as the upper bound
# roots: [-56.89293364+20.30999179j -56.89293364-20.30999179j]
# returning zero as the upper bound
# roots: [-44.64776691+31.16655447j -44.64776691-31.16655447j]
# returning zero as the upper bound
# roots: [-30.12022542+35.29074046j -30.12022542-35.29074046j]
# returning zero as the upper bound
# roots: [-14.37965675+32.64914673j -14.37965675-32.64914673j]
# returning zero as the upper bound
# roots: [2.11056717+18.61335154j 2.11056717-18.61335154j]
# returning zero as the upper bound
# rep 200/2500
# roots: [-30.4369631+8.02844944j -30.4369631-8.02844944j]
# returning zero as the upper bound
# roots: [-30.4369631+8.02844944j -30.4369631-8.02844944j]
# returning zero as the upper bound
# roots: [-30.43696325+8.0284494j -30.43696325-8.0284494j]
# returning zero as the upper bound
# roots: [-35.95639932+12.14095675j -35.95639932-12.14095675j]
# returning zero as the upper bound
# roots: [-23.49016458+13.85409134j -23.49016458-13.85409134j]
# returning zero as the upper bound
# roots: [-35.95639932+12.14095675j -35.95639932-12.14095675j]
# returning zero as the upper bound
# roots: [-23.49016458+13.85409134j -23.49016458-13.85409134j]
# returning zero as the upper bound
# roots: [-35.95639947+12.14095665j -35.95639947-12.14095665j]
# returning zero as the upper bound
# roots: [-23.49016518+13.85409153j -23.49016518-13.85409153j]
# returning zero as the upper bound
# roots: [-39.43711757+14.65808808j -39.43711757-14.65808808j]
# returning zero as the upper bound
# roots: [-26.51525361+19.24899668j -26.51525361-19.24899668j]
# returning zero as the upper bound
# roots: [-11.18488495+11.04922235j -11.18488495-11.04922235j]
# returning zero as the upper bound
# roots: [-39.43711757+14.65808808j -39.43711757-14.65808808j]
# returning zero as the upper bound
# roots: [-26.51525361+19.24899668j -26.51525361-19.24899668j]
# returning zero as the upper bound
# roots: [-11.18488495+11.04922235j -11.18488495-11.04922235j]
# returning zero as the upper bound
# roots: [-39.43711772+14.65808795j -39.43711772-14.65808795j]
# returning zero as the upper bound
# roots: [-26.51525423+19.2489967j -26.51525423-19.2489967j]
# returning zero as the upper bound
# roots: [-11.18488656+11.04922465j -11.18488656-11.04922465j]
# returning zero as the upper bound
# roots: [-51.73624115+19.12632344j -51.73624115-19.12632344j]
# returning zero as the upper bound
# roots: [-39.02361728+28.59712324j -39.02361728-28.59712324j]
# returning zero as the upper bound
# roots: [-23.94148895+30.57474447j -23.94148895-30.57474447j]
# returning zero as the upper bound
# roots: [-7.60002534+23.41149321j -7.60002534-23.41149321j]
# returning zero as the upper bound
# roots: [-51.73624115+19.12632344j -51.73624115-19.12632344j]
# returning zero as the upper bound
# roots: [-39.02361728+28.59712324j -39.02361728-28.59712324j]
# returning zero as the upper bound
# roots: [-23.94148895+30.57474447j -23.94148895-30.57474447j]
# returning zero as the upper bound
# roots: [-7.60002534+23.41149321j -7.60002534-23.41149321j]
# returning zero as the upper bound
# roots: [-51.73624131+19.12632324j -51.73624131-19.12632324j]
# returning zero as the upper bound
# roots: [-39.02361789+28.597123j -39.02361789-28.597123j]
# returning zero as the upper bound
# roots: [-23.94149054+30.57474466j -23.94149054-30.57474466j]
# returning zero as the upper bound
# roots: [-7.60002894+23.41149629j -7.60002894-23.41149629j]
# returning zero as the upper bound
# roots: [-28.68459576+5.95017849j -28.68459576-5.95017849j]
# returning zero as the upper bound
# roots: [-28.68459576+5.95017849j -28.68459576-5.95017849j]
# returning zero as the upper bound
# roots: [-28.68459591+5.9501785j -28.68459591-5.9501785j]
# returning zero as the upper bound
# rep 300/2500
# roots: [-29.94291967+7.9394888j -29.94291967-7.9394888j]
# returning zero as the upper bound
# roots: [-29.94291967+7.9394888j -29.94291967-7.9394888j]
# returning zero as the upper bound
# roots: [-29.94291983+7.93948877j -29.94291983-7.93948877j]
# returning zero as the upper bound
# roots: [-29.17927696+5.92590741j -29.17927696-5.92590741j]
# returning zero as the upper bound
# roots: [-29.17927696+5.92590741j -29.17927696-5.92590741j]
# returning zero as the upper bound
# roots: [-29.17927712+5.92590743j -29.17927712-5.92590743j]
# returning zero as the upper bound
# roots: [-25.57194404+5.97544146j -25.57194404-5.97544146j]
# returning zero as the upper bound
# roots: [-25.57194404+5.97544146j -25.57194404-5.97544146j]
# returning zero as the upper bound
# roots: [-25.57194421+5.97544149j -25.57194421-5.97544149j]
# returning zero as the upper bound
# rep 400/2500
# roots: [-43.8731533+16.36440066j -43.8731533-16.36440066j]
# returning zero as the upper bound
# roots: [-31.16495354+23.08336851j -31.16495354-23.08336851j]
# returning zero as the upper bound
# roots: [-16.08807393+20.69734808j -16.08807393-20.69734808j]
# returning zero as the upper bound
# roots: [-43.8731533+16.36440066j -43.8731533-16.36440066j]
# returning zero as the upper bound
# roots: [-31.16495354+23.08336851j -31.16495354-23.08336851j]
# returning zero as the upper bound
# roots: [-16.08807393+20.69734808j -16.08807393-20.69734808j]
# returning zero as the upper bound
# roots: [-43.87315345+16.3644005j -43.87315345-16.3644005j]
# returning zero as the upper bound
# roots: [-31.16495415+23.0833684j -31.16495415-23.0833684j]
# returning zero as the upper bound
# roots: [-16.08807552+20.69734893j -16.08807552-20.69734893j]
# returning zero as the upper bound
# roots: [-40.37961465+13.67595397j -40.37961465-13.67595397j]
# returning zero as the upper bound
# roots: [-28.10740862+17.73475899j -28.10740862-17.73475899j]
# returning zero as the upper bound
# roots: [-13.54778756+8.66678945j -13.54778756-8.66678945j]
# returning zero as the upper bound
# roots: [-40.37961465+13.67595397j -40.37961465-13.67595397j]
# returning zero as the upper bound
# roots: [-28.10740862+17.73475899j -28.10740862-17.73475899j]
# returning zero as the upper bound
# roots: [-13.54778756+8.66678945j -13.54778756-8.66678945j]
# returning zero as the upper bound
# roots: [-40.3796148+13.67595385j -40.3796148-13.67595385j]
# returning zero as the upper bound
# roots: [-28.10740921+17.73475902j -28.10740921-17.73475902j]
# returning zero as the upper bound
# roots: [-13.54778909+8.66679219j -13.54778909-8.66679219j]
# returning zero as the upper bound
# roots: [-24.03969353+0.881424j -24.03969353-0.881424j]
# returning zero as the upper bound
# roots: [-24.03969353+0.881424j -24.03969353-0.881424j]
# returning zero as the upper bound
# roots: [-24.03969369+0.88142462j -24.03969369-0.88142462j]
# returning zero as the upper bound
# rep 500/2500
# roots: [-36.54358789+12.63347587j -36.54358789-12.63347587j]
# returning zero as the upper bound
# roots: [-24.14418835+15.16445961j -24.14418835-15.16445961j]
# returning zero as the upper bound
# roots: [-36.54358789+12.63347587j -36.54358789-12.63347587j]
# returning zero as the upper bound
# roots: [-24.14418835+15.16445961j -24.14418835-15.16445961j]
# returning zero as the upper bound
# roots: [-36.54358804+12.63347577j -36.54358804-12.63347577j]
# returning zero as the upper bound
# roots: [-24.14418895+15.16445974j -24.14418895-15.16445974j]
# returning zero as the upper bound
# roots: [-33.48647601+10.05946028j -33.48647601-10.05946028j]
# returning zero as the upper bound
# roots: [-21.6862679+9.06371322j -21.6862679-9.06371322j]
# returning zero as the upper bound
# roots: [-33.48647601+10.05946028j -33.48647601-10.05946028j]
# returning zero as the upper bound
# roots: [-21.6862679+9.06371322j -21.6862679-9.06371322j]
# returning zero as the upper bound
# roots: [-33.48647615+10.05946021j -33.48647615-10.05946021j]
# returning zero as the upper bound
# roots: [-21.68626847+9.06371364j -21.68626847-9.06371364j]
# returning zero as the upper bound
# roots: [-26.92183213+5.44651179j -26.92183213-5.44651179j]
# returning zero as the upper bound
# roots: [-26.92183213+5.44651179j -26.92183213-5.44651179j]
# returning zero as the upper bound
# roots: [-26.92183227+5.4465118j -26.92183227-5.4465118j]
# returning zero as the upper bound
# roots: [-28.90236232+9.04234395j -28.90236232-9.04234395j]
# returning zero as the upper bound
# roots: [-28.90236232+9.04234395j -28.90236232-9.04234395j]
# returning zero as the upper bound
# roots: [-28.90236249+9.04234391j -28.90236249-9.04234391j]
# returning zero as the upper bound
# rep 600/2500
# roots: [-26.20661271+1.78358384j -26.20661271-1.78358384j]
# returning zero as the upper bound
# roots: [-26.20661271+1.78358384j -26.20661271-1.78358384j]
# returning zero as the upper bound
# roots: [-26.20661286+1.78358409j -26.20661286-1.78358409j]
# returning zero as the upper bound
# roots: [-26.44831108+1.18304957j -26.44831108-1.18304957j]
# returning zero as the upper bound
# roots: [-26.44831108+1.18304957j -26.44831108-1.18304957j]
# returning zero as the upper bound
# roots: [-26.44831123+1.18304997j -26.44831123-1.18304997j]
# returning zero as the upper bound
# roots: [-28.15815693+5.07221999j -28.15815693-5.07221999j]
# returning zero as the upper bound
# roots: [-28.15815693+5.07221999j -28.15815693-5.07221999j]
# returning zero as the upper bound
# roots: [-28.15815707+5.07222002j -28.15815707-5.07222002j]
# returning zero as the upper bound
# roots: [-25.44287093+3.95917838j -25.44287093-3.95917838j]
# returning zero as the upper bound
# roots: [-25.44287093+3.95917838j -25.44287093-3.95917838j]
# returning zero as the upper bound
# roots: [-25.44287109+3.95917848j -25.44287109-3.95917848j]
# returning zero as the upper bound
# roots: [-34.6945969+12.9878045j -34.6945969-12.9878045j]
# returning zero as the upper bound
# roots: [-21.35052293+14.80903929j -21.35052293-14.80903929j]
# returning zero as the upper bound
# roots: [-34.6945969+12.9878045j -34.6945969-12.9878045j]
# returning zero as the upper bound
# roots: [-21.35052293+14.80903929j -21.35052293-14.80903929j]
# returning zero as the upper bound
# roots: [-34.69459706+12.98780439j -34.69459706-12.98780439j]
# returning zero as the upper bound
# roots: [-21.35052357+14.80903949j -21.35052357-14.80903949j]
# returning zero as the upper bound
# roots: [-29.37260843+5.64344041j -29.37260843-5.64344041j]
# returning zero as the upper bound
# roots: [-29.37260843+5.64344041j -29.37260843-5.64344041j]
# returning zero as the upper bound
# roots: [-29.37260858+5.64344043j -29.37260858-5.64344043j]
# returning zero as the upper bound
# rep 700/2500
# roots: [-33.10920682+9.98456444j -33.10920682-9.98456444j]
# returning zero as the upper bound
# roots: [-21.42008053+9.04214745j -21.42008053-9.04214745j]
# returning zero as the upper bound
# roots: [-33.10920682+9.98456444j -33.10920682-9.98456444j]
# returning zero as the upper bound
# roots: [-21.42008053+9.04214745j -21.42008053-9.04214745j]
# returning zero as the upper bound
# roots: [-33.10920697+9.98456437j -33.10920697-9.98456437j]
# returning zero as the upper bound
# roots: [-21.42008109+9.04214786j -21.42008109-9.04214786j]
# returning zero as the upper bound
# roots: [-25.84317848+2.17282034j -25.84317848-2.17282034j]
# returning zero as the upper bound
# roots: [-25.84317848+2.17282034j -25.84317848-2.17282034j]
# returning zero as the upper bound
# roots: [-25.84317865+2.1728206j -25.84317865-2.1728206j]
# returning zero as the upper bound
# rep 800/2500
# roots: [-45.0865289+14.03325426j -45.0865289-14.03325426j]
# returning zero as the upper bound
# roots: [-33.50741329+19.19665842j -33.50741329-19.19665842j]
# returning zero as the upper bound
# roots: [-19.77006769+14.97634349j -19.77006769-14.97634349j]
# returning zero as the upper bound
# roots: [-13.69962878+6.34970249j -13.69962878-6.34970249j]
# returning zero as the upper bound
# roots: [-45.0865289+14.03325426j -45.0865289-14.03325426j]
# returning zero as the upper bound
# roots: [-33.50741329+19.19665842j -33.50741329-19.19665842j]
# returning zero as the upper bound
# roots: [-19.77006769+14.97634349j -19.77006769-14.97634349j]
# returning zero as the upper bound
# roots: [-13.69962878+6.34970249j -13.69962878-6.34970249j]
# returning zero as the upper bound
# roots: [-45.08652904+14.03325412j -45.08652904-14.03325412j]
# returning zero as the upper bound
# roots: [-33.50741385+19.19665838j -33.50741385-19.19665838j]
# returning zero as the upper bound
# roots: [-19.77006914+14.97634466j -19.77006914-14.97634466j]
# returning zero as the upper bound
# roots: [-24.64994137+5.34559659j -24.64994137-5.34559659j]
# returning zero as the upper bound
# roots: [-24.64994137+5.34559659j -24.64994137-5.34559659j]
# returning zero as the upper bound
# roots: [-24.64994153+5.34559663j -24.64994153-5.34559663j]
# returning zero as the upper bound
# rep 900/2500
# roots: [-22.92297608+2.15577479j -22.92297608-2.15577479j]
# returning zero as the upper bound
# roots: [-22.92297608+2.15577479j -22.92297608-2.15577479j]
# returning zero as the upper bound
# roots: [-22.92297624+2.155775j -22.92297624-2.155775j]
# returning zero as the upper bound
# rep 1000/2500
# roots: [-39.53769802+12.85274209j -39.53769802-12.85274209j]
# returning zero as the upper bound
# roots: [-28.41469452+17.08710564j -28.41469452-17.08710564j]
# returning zero as the upper bound
# roots: [-15.21847571+11.02058988j -15.21847571-11.02058988j]
# returning zero as the upper bound
# roots: [-39.53769802+12.85274209j -39.53769802-12.85274209j]
# returning zero as the upper bound
# roots: [-28.41469452+17.08710564j -28.41469452-17.08710564j]
# returning zero as the upper bound
# roots: [-15.21847571+11.02058988j -15.21847571-11.02058988j]
# returning zero as the upper bound
# roots: [-39.53769816+12.85274197j -39.53769816-12.85274197j]
# returning zero as the upper bound
# roots: [-28.41469505+17.08710564j -28.41469505-17.08710564j]
# returning zero as the upper bound
# roots: [-15.2184771+11.02059152j -15.2184771-11.02059152j]
# returning zero as the upper bound
# roots: [-29.14406381+6.62010737j -29.14406381-6.62010737j]
# returning zero as the upper bound
# roots: [-29.14406381+6.62010737j -29.14406381-6.62010737j]
# returning zero as the upper bound
# roots: [-29.14406396+6.62010736j -29.14406396-6.62010736j]
# returning zero as the upper bound
# rep 1100/2500
# roots: [-29.94981224+9.78300453j -29.94981224-9.78300453j]
# returning zero as the upper bound
# roots: [-29.94981224+9.78300453j -29.94981224-9.78300453j]
# returning zero as the upper bound
# roots: [-29.94981241+9.78300448j -29.94981241-9.78300448j]
# returning zero as the upper bound
# roots: [-36.83695805+12.22789403j -36.83695805-12.22789403j]
# returning zero as the upper bound
# roots: [-24.35580884+14.05458073j -24.35580884-14.05458073j]
# returning zero as the upper bound
# roots: [-36.83695805+12.22789403j -36.83695805-12.22789403j]
# returning zero as the upper bound
# roots: [-24.35580884+14.05458073j -24.35580884-14.05458073j]
# returning zero as the upper bound
# roots: [-36.8369582+12.22789392j -36.8369582-12.22789392j]
# returning zero as the upper bound
# roots: [-24.35580944+14.05458091j -24.35580944-14.05458091j]
# returning zero as the upper bound
# roots: [-25.93024543+4.51827256j -25.93024543-4.51827256j]
# returning zero as the upper bound
# roots: [-25.93024543+4.51827256j -25.93024543-4.51827256j]
# returning zero as the upper bound
# roots: [-25.93024558+4.51827262j -25.93024558-4.51827262j]
# returning zero as the upper bound
# roots: [-39.84713008+14.0689671j -39.84713008-14.0689671j]
# returning zero as the upper bound
# roots: [-26.99490764+18.00089085j -26.99490764-18.00089085j]
# returning zero as the upper bound
# roots: [-11.74716098+6.72087492j -11.74716098-6.72087492j]
# returning zero as the upper bound
# roots: [-39.84713008+14.0689671j -39.84713008-14.0689671j]
# returning zero as the upper bound
# roots: [-26.99490764+18.00089085j -26.99490764-18.00089085j]
# returning zero as the upper bound
# roots: [-11.74716098+6.72087492j -11.74716098-6.72087492j]
# returning zero as the upper bound
# roots: [-39.84713024+14.06896698j -39.84713024-14.06896698j]
# returning zero as the upper bound
# roots: [-26.99490825+18.0008909j -26.99490825-18.0008909j]
# returning zero as the upper bound
# roots: [-11.74716258+6.72087891j -11.74716258-6.72087891j]
# returning zero as the upper bound
# roots: [-27.61287009+8.58981404j -27.61287009-8.58981404j]
# returning zero as the upper bound
# roots: [-27.61287009+8.58981404j -27.61287009-8.58981404j]
# returning zero as the upper bound
# roots: [-27.61287026+8.58981401j -27.61287026-8.58981401j]
# returning zero as the upper bound
# roots: [-26.20774859+1.49715978j -26.20774859-1.49715978j]
# returning zero as the upper bound
# roots: [-26.20774859+1.49715978j -26.20774859-1.49715978j]
# returning zero as the upper bound
# roots: [-26.20774875+1.49716013j -26.20774875-1.49716013j]
# returning zero as the upper bound
# rep 1200/2500
# roots: [-26.58249436+5.41805992j -26.58249436-5.41805992j]
# returning zero as the upper bound
# roots: [-26.58249436+5.41805992j -26.58249436-5.41805992j]
# returning zero as the upper bound
# roots: [-26.58249451+5.41805994j -26.58249451-5.41805994j]
# returning zero as the upper bound
# roots: [-35.15128234+13.55235639j -35.15128234-13.55235639j]
# returning zero as the upper bound
# roots: [-20.87016485+14.94800674j -20.87016485-14.94800674j]
# returning zero as the upper bound
# roots: [-35.15128234+13.55235639j -35.15128234-13.55235639j]
# returning zero as the upper bound
# roots: [-20.87016485+14.94800674j -20.87016485-14.94800674j]
# returning zero as the upper bound
# roots: [-35.15128251+13.55235628j -35.15128251-13.55235628j]
# returning zero as the upper bound
# roots: [-20.87016553+14.948007j -20.87016553-14.948007j]
# returning zero as the upper bound
# roots: [-35.11473666+12.68346523j -35.11473666-12.68346523j]
# returning zero as the upper bound
# roots: [-22.1748458+14.58668218j -22.1748458-14.58668218j]
# returning zero as the upper bound
# roots: [-16.00791457+10.93965145j -16.00791457-10.93965145j]
# returning zero as the upper bound
# roots: [-11.93989112+4.07792821j -11.93989112-4.07792821j]
# returning zero as the upper bound
# roots: [-35.11473666+12.68346523j -35.11473666-12.68346523j]
# returning zero as the upper bound
# roots: [-22.1748458+14.58668218j -22.1748458-14.58668218j]
# returning zero as the upper bound
# roots: [-16.00791457+10.93965145j -16.00791457-10.93965145j]
# returning zero as the upper bound
# roots: [-11.93989112+4.07792821j -11.93989112-4.07792821j]
# returning zero as the upper bound
# roots: [-35.11473681+12.68346512j -35.11473681-12.68346512j]
# returning zero as the upper bound
# roots: [-22.17484642+14.58668237j -22.17484642-14.58668237j]
# returning zero as the upper bound
# rep 1300/2500
# roots: [-28.81142862+6.46522459j -28.81142862-6.46522459j]
# returning zero as the upper bound
# roots: [-28.81142862+6.46522459j -28.81142862-6.46522459j]
# returning zero as the upper bound
# roots: [-28.81142878+6.4652246j -28.81142878-6.4652246j]
# returning zero as the upper bound
# roots: [-42.96789412+17.01513014j -42.96789412-17.01513014j]
# returning zero as the upper bound
# roots: [-29.32264465+23.63030765j -29.32264465-23.63030765j]
# returning zero as the upper bound
# roots: [-13.13405874+19.85992273j -13.13405874-19.85992273j]
# returning zero as the upper bound
# roots: [-5.98043352+12.44892413j -5.98043352-12.44892413j]
# returning zero as the upper bound
# roots: [-3.77897062+7.79070629j -3.77897062-7.79070629j]
# returning zero as the upper bound
# roots: [-4.90566727+10.49563427j -4.90566727-10.49563427j]
# returning zero as the upper bound
# roots: [-5.44926047+11.53753549j -5.44926047-11.53753549j]
# returning zero as the upper bound
# roots: [-5.17905011+11.03527938j -5.17905011-11.03527938j]
# returning zero as the upper bound
# roots: [-42.96789412+17.01513014j -42.96789412-17.01513014j]
# returning zero as the upper bound
# roots: [-29.32264465+23.63030765j -29.32264465-23.63030765j]
# returning zero as the upper bound
# roots: [-13.13405874+19.85992273j -13.13405874-19.85992273j]
# returning zero as the upper bound
# roots: [-5.98043352+12.44892413j -5.98043352-12.44892413j]
# returning zero as the upper bound
# roots: [-3.77897062+7.79070629j -3.77897062-7.79070629j]
# returning zero as the upper bound
# roots: [-4.90566727+10.49563427j -4.90566727-10.49563427j]
# returning zero as the upper bound
# roots: [-5.44926047+11.53753549j -5.44926047-11.53753549j]
# returning zero as the upper bound
# roots: [-5.17905011+11.03527938j -5.17905011-11.03527938j]
# returning zero as the upper bound
# roots: [-42.96789429+17.01512998j -42.96789429-17.01512998j]
# returning zero as the upper bound
# roots: [-29.3226453+23.63030757j -29.3226453-23.63030757j]
# returning zero as the upper bound
# roots: [-13.13406044+19.85992386j -13.13406044-19.85992386j]
# returning zero as the upper bound
# roots: [-33.77544062+10.95726133j -33.77544062-10.95726133j]
# returning zero as the upper bound
# roots: [-22.05357815+11.82557588j -22.05357815-11.82557588j]
# returning zero as the upper bound
# roots: [-33.77544062+10.95726133j -33.77544062-10.95726133j]
# returning zero as the upper bound
# roots: [-22.05357815+11.82557588j -22.05357815-11.82557588j]
# returning zero as the upper bound
# roots: [-33.77544077+10.95726124j -33.77544077-10.95726124j]
# returning zero as the upper bound
# roots: [-22.05357872+11.82557612j -22.05357872-11.82557612j]
# returning zero as the upper bound
# roots: [-34.60540312+10.78641159j -34.60540312-10.78641159j]
# returning zero as the upper bound
# roots: [-21.89917598+9.61220964j -21.89917598-9.61220964j]
# returning zero as the upper bound
# roots: [-34.60540312+10.78641159j -34.60540312-10.78641159j]
# returning zero as the upper bound
# roots: [-21.89917598+9.61220964j -21.89917598-9.61220964j]
# returning zero as the upper bound
# roots: [-34.60540328+10.78641151j -34.60540328-10.78641151j]
# returning zero as the upper bound
# roots: [-21.89917659+9.6122101j -21.89917659-9.6122101j]
# returning zero as the upper bound
# roots: [-36.62289397+11.70845491j -36.62289397-11.70845491j]
# returning zero as the upper bound
# roots: [-24.42125689+13.11025367j -24.42125689-13.11025367j]
# returning zero as the upper bound
# roots: [-36.62289397+11.70845491j -36.62289397-11.70845491j]
# returning zero as the upper bound
# roots: [-24.42125689+13.11025367j -24.42125689-13.11025367j]
# returning zero as the upper bound
# roots: [-36.62289412+11.70845481j -36.62289412-11.70845481j]
# returning zero as the upper bound
# roots: [-24.42125747+13.11025387j -24.42125747-13.11025387j]
# returning zero as the upper bound
# rep 1400/2500
# roots: [-35.66332782+11.58822604j -35.66332782-11.58822604j]
# returning zero as the upper bound
# roots: [-23.17391815+12.36541836j -23.17391815-12.36541836j]
# returning zero as the upper bound
# roots: [-35.66332782+11.58822604j -35.66332782-11.58822604j]
# returning zero as the upper bound
# roots: [-23.17391815+12.36541836j -23.17391815-12.36541836j]
# returning zero as the upper bound
# roots: [-35.66332798+11.58822595j -35.66332798-11.58822595j]
# returning zero as the upper bound
# roots: [-23.17391874+12.36541862j -23.17391874-12.36541862j]
# returning zero as the upper bound
# roots: [-27.38970326+8.4135758j -27.38970326-8.4135758j]
# returning zero as the upper bound
# roots: [-27.38970326+8.4135758j -27.38970326-8.4135758j]
# returning zero as the upper bound
# roots: [-27.38970342+8.41357577j -27.38970342-8.41357577j]
# returning zero as the upper bound
# rep 1500/2500
# roots: [-34.93294195+10.91886627j -34.93294195-10.91886627j]
# returning zero as the upper bound
# roots: [-22.48729381+10.52353961j -22.48729381-10.52353961j]
# returning zero as the upper bound
# roots: [-34.93294195+10.91886627j -34.93294195-10.91886627j]
# returning zero as the upper bound
# roots: [-22.48729381+10.52353961j -22.48729381-10.52353961j]
# returning zero as the upper bound
# roots: [-34.93294211+10.91886619j -34.93294211-10.91886619j]
# returning zero as the upper bound
# roots: [-22.48729441+10.52353999j -22.48729441-10.52353999j]
# returning zero as the upper bound
# roots: [-33.09051579+11.15096075j -33.09051579-11.15096075j]
# returning zero as the upper bound
# roots: [-20.95123125+11.7099236j -20.95123125-11.7099236j]
# returning zero as the upper bound
# roots: [-33.09051579+11.15096075j -33.09051579-11.15096075j]
# returning zero as the upper bound
# roots: [-20.95123125+11.7099236j -20.95123125-11.7099236j]
# returning zero as the upper bound
# roots: [-33.09051594+11.15096066j -33.09051594-11.15096066j]
# returning zero as the upper bound
# roots: [-20.95123184+11.70992387j -20.95123184-11.70992387j]
# returning zero as the upper bound
# roots: [-33.650416+13.0608872j -33.650416-13.0608872j]
# returning zero as the upper bound
# roots: [-19.97867463+14.5380614j -19.97867463-14.5380614j]
# returning zero as the upper bound
# roots: [-33.650416+13.0608872j -33.650416-13.0608872j]
# returning zero as the upper bound
# roots: [-19.97867463+14.5380614j -19.97867463-14.5380614j]
# returning zero as the upper bound
# roots: [-33.65041617+13.06088709j -33.65041617-13.06088709j]
# returning zero as the upper bound
# roots: [-19.97867529+14.53806164j -19.97867529-14.53806164j]
# returning zero as the upper bound
# roots: [-32.78900572+10.28375779j -32.78900572-10.28375779j]
# returning zero as the upper bound
# roots: [-20.29111328+8.34204155j -20.29111328-8.34204155j]
# returning zero as the upper bound
# roots: [-32.78900572+10.28375779j -32.78900572-10.28375779j]
# returning zero as the upper bound
# roots: [-20.29111328+8.34204155j -20.29111328-8.34204155j]
# returning zero as the upper bound
# roots: [-32.78900588+10.28375772j -32.78900588-10.28375772j]
# returning zero as the upper bound
# roots: [-20.29111387+8.3420421j -20.29111387-8.3420421j]
# returning zero as the upper bound
# roots: [-34.36173925+12.9845547j -34.36173925-12.9845547j]
# returning zero as the upper bound
# roots: [-21.02564434+14.81170287j -21.02564434-14.81170287j]
# returning zero as the upper bound
# roots: [-34.36173925+12.9845547j -34.36173925-12.9845547j]
# returning zero as the upper bound
# roots: [-21.02564434+14.81170287j -21.02564434-14.81170287j]
# returning zero as the upper bound
# roots: [-34.36173941+12.98455459j -34.36173941-12.98455459j]
# returning zero as the upper bound
# roots: [-21.02564498+14.81170308j -21.02564498-14.81170308j]
# returning zero as the upper bound
# roots: [-35.36482764+10.91794953j -35.36482764-10.91794953j]
# returning zero as the upper bound
# roots: [-23.10635788+10.85049677j -23.10635788-10.85049677j]
# returning zero as the upper bound
# roots: [-35.36482764+10.91794953j -35.36482764-10.91794953j]
# returning zero as the upper bound
# roots: [-23.10635788+10.85049677j -23.10635788-10.85049677j]
# returning zero as the upper bound
# roots: [-35.36482779+10.91794945j -35.36482779-10.91794945j]
# returning zero as the upper bound
# roots: [-23.10635847+10.8504971j -23.10635847-10.8504971j]
# returning zero as the upper bound
# rep 1600/2500
# roots: [-34.58598927+13.25598282j -34.58598927-13.25598282j]
# returning zero as the upper bound
# roots: [-20.35112494+14.22469286j -20.35112494-14.22469286j]
# returning zero as the upper bound
# roots: [-34.58598927+13.25598282j -34.58598927-13.25598282j]
# returning zero as the upper bound
# roots: [-20.35112494+14.22469286j -20.35112494-14.22469286j]
# returning zero as the upper bound
# roots: [-34.58598945+13.25598272j -34.58598945-13.25598272j]
# returning zero as the upper bound
# roots: [-20.35112562+14.22469315j -20.35112562-14.22469315j]
# returning zero as the upper bound
# rep 1700/2500
# roots: [-30.98828177+7.9493787j -30.98828177-7.9493787j]
# returning zero as the upper bound
# roots: [-30.98828177+7.9493787j -30.98828177-7.9493787j]
# returning zero as the upper bound
# roots: [-30.98828192+7.94937867j -30.98828192-7.94937867j]
# returning zero as the upper bound
# roots: [-30.46411071+8.02729689j -30.46411071-8.02729689j]
# returning zero as the upper bound
# roots: [-30.46411071+8.02729689j -30.46411071-8.02729689j]
# returning zero as the upper bound
# roots: [-30.46411085+8.02729685j -30.46411085-8.02729685j]
# returning zero as the upper bound
# roots: [-24.21274475+5.22776003j -24.21274475-5.22776003j]
# returning zero as the upper bound
# roots: [-24.21274475+5.22776003j -24.21274475-5.22776003j]
# returning zero as the upper bound
# roots: [-24.21274491+5.22776008j -24.21274491-5.22776008j]
# returning zero as the upper bound
# rep 1800/2500
# roots: [-32.3860278+10.21801842j -32.3860278-10.21801842j]
# returning zero as the upper bound
# roots: [-19.27173929+6.45066921j -19.27173929-6.45066921j]
# returning zero as the upper bound
# roots: [-32.3860278+10.21801842j -32.3860278-10.21801842j]
# returning zero as the upper bound
# roots: [-19.27173929+6.45066921j -19.27173929-6.45066921j]
# returning zero as the upper bound
# roots: [-32.38602796+10.21801835j -32.38602796-10.21801835j]
# returning zero as the upper bound
# roots: [-19.27173992+6.45067009j -19.27173992-6.45067009j]
# returning zero as the upper bound
# roots: [-32.47693642+12.00273011j -32.47693642-12.00273011j]
# returning zero as the upper bound
# roots: [-19.0214164+11.96451197j -19.0214164-11.96451197j]
# returning zero as the upper bound
# roots: [-32.47693642+12.00273011j -32.47693642-12.00273011j]
# returning zero as the upper bound
# roots: [-19.0214164+11.96451197j -19.0214164-11.96451197j]
# returning zero as the upper bound
# roots: [-32.47693659+12.00273002j -32.47693659-12.00273002j]
# returning zero as the upper bound
# roots: [-19.02141704+11.96451234j -19.02141704-11.96451234j]
# returning zero as the upper bound
# roots: [-48.81659434+16.46598661j -48.81659434-16.46598661j]
# returning zero as the upper bound
# roots: [-37.22261388+24.1620986j -37.22261388-24.1620986j]
# returning zero as the upper bound
# roots: [-23.46763278+24.61891316j -23.46763278-24.61891316j]
# returning zero as the upper bound
# roots: [-8.56413121+14.25214689j -8.56413121-14.25214689j]
# returning zero as the upper bound
# roots: [-48.81659434+16.46598661j -48.81659434-16.46598661j]
# returning zero as the upper bound
# roots: [-37.22261388+24.1620986j -37.22261388-24.1620986j]
# returning zero as the upper bound
# roots: [-23.46763278+24.61891316j -23.46763278-24.61891316j]
# returning zero as the upper bound
# roots: [-8.56413121+14.25214689j -8.56413121-14.25214689j]
# returning zero as the upper bound
# roots: [-48.81659448+16.46598644j -48.81659448-16.46598644j]
# returning zero as the upper bound
# roots: [-37.22261444+24.16209842j -37.22261444-24.16209842j]
# returning zero as the upper bound
# roots: [-23.46763422+24.61891352j -23.46763422-24.61891352j]
# returning zero as the upper bound
# roots: [-8.56413449+14.25215172j -8.56413449-14.25215172j]
# returning zero as the upper bound
# rep 1900/2500
# roots: [-35.01342325+13.07678057j -35.01342325-13.07678057j]
# returning zero as the upper bound
# roots: [-22.03238114+15.51183787j -22.03238114-15.51183787j]
# returning zero as the upper bound
# roots: [-35.01342325+13.07678057j -35.01342325-13.07678057j]
# returning zero as the upper bound
# roots: [-22.03238114+15.51183787j -22.03238114-15.51183787j]
# returning zero as the upper bound
# roots: [-35.0134234+13.07678045j -35.0134234-13.07678045j]
# returning zero as the upper bound
# roots: [-22.03238176+15.51183803j -22.03238176-15.51183803j]
# returning zero as the upper bound
# rep 2000/2500
# roots: [-23.62000785+4.10308311j -23.62000785-4.10308311j]
# returning zero as the upper bound
# roots: [-23.62000785+4.10308311j -23.62000785-4.10308311j]
# returning zero as the upper bound
# roots: [-23.62000803+4.10308322j -23.62000803-4.10308322j]
# returning zero as the upper bound
# roots: [-42.50487203+15.05252877j -42.50487203-15.05252877j]
# returning zero as the upper bound
# roots: [-31.31445851+21.63870363j -31.31445851-21.63870363j]
# returning zero as the upper bound
# roots: [-18.03826513+20.73902086j -18.03826513-20.73902086j]
# returning zero as the upper bound
# roots: [-42.50487203+15.05252877j -42.50487203-15.05252877j]
# returning zero as the upper bound
# roots: [-31.31445851+21.63870363j -31.31445851-21.63870363j]
# returning zero as the upper bound
# roots: [-18.03826513+20.73902086j -18.03826513-20.73902086j]
# returning zero as the upper bound
# roots: [-42.50487217+15.05252862j -42.50487217-15.05252862j]
# returning zero as the upper bound
# roots: [-31.31445904+21.63870351j -31.31445904-21.63870351j]
# returning zero as the upper bound
# roots: [-18.03826652+20.7390214j -18.03826652-20.7390214j]
# returning zero as the upper bound
# roots: [-35.31467039+15.19197872j -35.31467039-15.19197872j]
# returning zero as the upper bound
# roots: [-19.8683148+17.54267416j -19.8683148-17.54267416j]
# returning zero as the upper bound
# roots: [-35.31467039+15.19197872j -35.31467039-15.19197872j]
# returning zero as the upper bound
# roots: [-19.8683148+17.54267416j -19.8683148-17.54267416j]
# returning zero as the upper bound
# roots: [-35.31467058+15.1919786j -35.31467058-15.1919786j]
# returning zero as the upper bound
# roots: [-19.86831554+17.54267438j -19.86831554-17.54267438j]
# returning zero as the upper bound
# rep 2100/2500
# roots: [-35.30583726+11.40145564j -35.30583726-11.40145564j]
# returning zero as the upper bound
# roots: [-23.28438048+12.565546j -23.28438048-12.565546j]
# returning zero as the upper bound
# roots: [-35.30583726+11.40145564j -35.30583726-11.40145564j]
# returning zero as the upper bound
# roots: [-23.28438048+12.565546j -23.28438048-12.565546j]
# returning zero as the upper bound
# roots: [-35.3058374+11.40145555j -35.3058374-11.40145555j]
# returning zero as the upper bound
# roots: [-23.28438105+12.56554623j -23.28438105-12.56554623j]
# returning zero as the upper bound
# roots: [-42.61497679+17.05107616j -42.61497679-17.05107616j]
# returning zero as the upper bound
# roots: [-28.04953438+22.8559411j -28.04953438-22.8559411j]
# returning zero as the upper bound
# roots: [-10.76924088+15.71379474j -10.76924088-15.71379474j]
# returning zero as the upper bound
# roots: [-42.61497679+17.05107616j -42.61497679-17.05107616j]
# returning zero as the upper bound
# roots: [-28.04953438+22.8559411j -28.04953438-22.8559411j]
# returning zero as the upper bound
# roots: [-10.76924088+15.71379474j -10.76924088-15.71379474j]
# returning zero as the upper bound
# roots: [-42.61497697+17.05107601j -42.61497697-17.05107601j]
# returning zero as the upper bound
# roots: [-28.04953508+22.85594108j -28.04953508-22.85594108j]
# returning zero as the upper bound
# roots: [-10.7692427+15.71379666j -10.7692427-15.71379666j]
# returning zero as the upper bound
# roots: [-54.38937608+20.88020641j -54.38937608-20.88020641j]
# returning zero as the upper bound
# roots: [-40.88098268+31.46580202j -40.88098268-31.46580202j]
# returning zero as the upper bound
# roots: [-24.85476144+34.26606613j -24.85476144-34.26606613j]
# returning zero as the upper bound
# roots: [-7.49037456+28.17430971j -7.49037456-28.17430971j]
# returning zero as the upper bound
# roots: [-54.38937608+20.88020641j -54.38937608-20.88020641j]
# returning zero as the upper bound
# roots: [-40.88098268+31.46580202j -40.88098268-31.46580202j]
# returning zero as the upper bound
# roots: [-24.85476144+34.26606613j -24.85476144-34.26606613j]
# returning zero as the upper bound
# roots: [-7.49037456+28.17430971j -7.49037456-28.17430971j]
# returning zero as the upper bound
# roots: [-54.38937624+20.8802062j -54.38937624-20.8802062j]
# returning zero as the upper bound
# roots: [-40.88098333+31.46580174j -40.88098333-31.46580174j]
# returning zero as the upper bound
# roots: [-24.85476312+34.26606624j -24.85476312-34.26606624j]
# returning zero as the upper bound
# roots: [-7.49037838+28.17431238j -7.49037838-28.17431238j]
# returning zero as the upper bound
# rep 2200/2500
# roots: [-26.57670668+6.93353379j -26.57670668-6.93353379j]
# returning zero as the upper bound
# roots: [-26.57670668+6.93353379j -26.57670668-6.93353379j]
# returning zero as the upper bound
# roots: [-26.57670685+6.93353379j -26.57670685-6.93353379j]
# returning zero as the upper bound
# roots: [-42.29350607+15.52534341j -42.29350607-15.52534341j]
# returning zero as the upper bound
# roots: [-28.84025651+20.62299479j -28.84025651-20.62299479j]
# returning zero as the upper bound
# roots: [-12.87945734+13.20811047j -12.87945734-13.20811047j]
# returning zero as the upper bound
# roots: [-42.29350607+15.52534341j -42.29350607-15.52534341j]
# returning zero as the upper bound
# roots: [-28.84025651+20.62299479j -28.84025651-20.62299479j]
# returning zero as the upper bound
# roots: [-12.87945734+13.20811047j -12.87945734-13.20811047j]
# returning zero as the upper bound
# roots: [-42.29350624+15.52534327j -42.29350624-15.52534327j]
# returning zero as the upper bound
# roots: [-28.84025715+20.62299478j -28.84025715-20.62299478j]
# returning zero as the upper bound
# roots: [-12.87945902+13.20811248j -12.87945902-13.20811248j]
# returning zero as the upper bound
# roots: [-26.21245423+3.02387518j -26.21245423-3.02387518j]
# returning zero as the upper bound
# roots: [-26.21245423+3.02387518j -26.21245423-3.02387518j]
# returning zero as the upper bound
# roots: [-26.21245438+3.02387531j -26.21245438-3.02387531j]
# returning zero as the upper bound
# roots: [-47.21416288+18.11916151j -47.21416288-18.11916151j]
# returning zero as the upper bound
# roots: [-34.2014078+26.39915025j -34.2014078-26.39915025j]
# returning zero as the upper bound
# roots: [-18.76320684+26.36285378j -18.76320684-26.36285378j]
# returning zero as the upper bound
# roots: [-2.03593906+12.445267j -2.03593906-12.445267j]
# returning zero as the upper bound
# roots: [-47.21416288+18.11916151j -47.21416288-18.11916151j]
# returning zero as the upper bound
# roots: [-34.2014078+26.39915025j -34.2014078-26.39915025j]
# returning zero as the upper bound
# roots: [-18.76320684+26.36285378j -18.76320684-26.36285378j]
# returning zero as the upper bound
# roots: [-2.03593906+12.445267j -2.03593906-12.445267j]
# returning zero as the upper bound
# roots: [-47.21416304+18.11916133j -47.21416304-18.11916133j]
# returning zero as the upper bound
# roots: [-34.20140843+26.39915006j -34.20140843-26.39915006j]
# returning zero as the upper bound
# roots: [-18.76320846+26.36285426j -18.76320846-26.36285426j]
# returning zero as the upper bound
# roots: [-2.03594275+12.44527425j -2.03594275-12.44527425j]
# returning zero as the upper bound
# rep 2300/2500
# roots: [-24.81156993+3.60752909j -24.81156993-3.60752909j]
# returning zero as the upper bound
# roots: [-24.81156993+3.60752909j -24.81156993-3.60752909j]
# returning zero as the upper bound
# roots: [-24.81157008+3.60752919j -24.81157008-3.60752919j]
# returning zero as the upper bound
# roots: [-30.99207048+9.77928832j -30.99207048-9.77928832j]
# returning zero as the upper bound
# roots: [-18.87820615+7.38598403j -18.87820615-7.38598403j]
# returning zero as the upper bound
# roots: [-30.99207048+9.77928832j -30.99207048-9.77928832j]
# returning zero as the upper bound
# roots: [-18.87820615+7.38598403j -18.87820615-7.38598403j]
# returning zero as the upper bound
# roots: [-30.99207063+9.77928826j -30.99207063-9.77928826j]
# returning zero as the upper bound
# roots: [-18.87820673+7.38598464j -18.87820673-7.38598464j]
# returning zero as the upper bound
# rep 2400/2500
# roots: [-33.74340107+11.36054996j -33.74340107-11.36054996j]
# returning zero as the upper bound
# roots: [-20.83794173+11.02745682j -20.83794173-11.02745682j]
# returning zero as the upper bound
# roots: [-33.74340107+11.36054996j -33.74340107-11.36054996j]
# returning zero as the upper bound
# roots: [-20.83794173+11.02745682j -20.83794173-11.02745682j]
# returning zero as the upper bound
# roots: [-33.74340123+11.36054988j -33.74340123-11.36054988j]
# returning zero as the upper bound
# roots: [-20.83794235+11.0274572j -20.83794235-11.0274572j]
# returning zero as the upper bound
# roots: [-34.70257695+11.70022233j -34.70257695-11.70022233j]
# returning zero as the upper bound
# roots: [-22.56646829+13.18137045j -22.56646829-13.18137045j]
# returning zero as the upper bound
# roots: [-34.70257695+11.70022233j -34.70257695-11.70022233j]
# returning zero as the upper bound
# roots: [-22.56646829+13.18137045j -22.56646829-13.18137045j]
# returning zero as the upper bound
# roots: [-34.7025771+11.70022223j -34.7025771-11.70022223j]
# returning zero as the upper bound
# roots: [-22.56646887+13.18137065j -22.56646887-13.18137065j]
# returning zero as the upper bound
# roots: [-37.51088818+15.82170426j -37.51088818-15.82170426j]
# returning zero as the upper bound
# roots: [-23.26878676+20.47039427j -23.26878676-20.47039427j]
# returning zero as the upper bound
# roots: [-6.37210173+9.64631855j -6.37210173-9.64631855j]
# returning zero as the upper bound
# roots: [-37.51088818+15.82170426j -37.51088818-15.82170426j]
# returning zero as the upper bound
# roots: [-23.26878676+20.47039427j -23.26878676-20.47039427j]
# returning zero as the upper bound
# roots: [-6.37210173+9.64631855j -6.37210173-9.64631855j]
# returning zero as the upper bound
# roots: [-37.51088836+15.82170411j -37.51088836-15.82170411j]
# returning zero as the upper bound
# roots: [-23.26878744+20.47039431j -23.26878744-20.47039431j]
# returning zero as the upper bound
# roots: [-6.37210351+9.64632188j -6.37210351-9.64632188j]
# returning zero as the upper bound
# roots: [-29.99074945+8.55118546j -29.99074945-8.55118546j]
# returning zero as the upper bound
# roots: [-29.99074945+8.55118546j -29.99074945-8.55118546j]
# returning zero as the upper bound
# roots: [-29.9907496+8.55118542j -29.9907496-8.55118542j]
# returning zero as the upper bound
# rep 2500/2500

# %%
def save_as_tsv(fn, cols, data): 
    with open(fn, 'w') as f:
        f.write("\t".join(cols) + "\n")
        for row in data:
            f.write("\t".join("%f"%v for v in row) +"\n")
    
cvals_and_by_breaks = zip(c_values, byas_break_MAP)
save_as_tsv("../results/logistic_regression/logistic_regression_cvals_and_calibration.tsv",
            ["c_value", "by_break"], cvals_and_by_breaks)
